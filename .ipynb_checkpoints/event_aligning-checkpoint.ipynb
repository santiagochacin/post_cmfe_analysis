# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import numpy as np
import pandas as pd
import h5py
import python_utils_jjm as utils_jjm
from tqdm import tqdm
from scipy import stats
from scipy import signal 
from importlib import reload
from matplotlib import pyplot as plt
import itertools
import miniscope_analysis as ma

# %%
dir_path = '/Volumes/My_Passport/cnmfe_analysis_files/OpenFieldAnalysis/'

# %%
session = pd.read_hdf(dir_path+'GRIN026_aligned_to_behavior.h5')

# %%
#get time where velocity crosses threshold 

sample_points = ma.count_events_in_array(session['behavior']['velocity_z_score'].values, 30, 0.1, threshold=3, up=True)[1]
sorted = []
fs = 20
time_sort = (5*20, 1*20)
for event in sample_points:
    if len(ma.count_events_in_array(session['behavior']['velocity_z_score'].values[event-time_sort[0]:event-time_sort[1]], 30, 0.1, threshold=3, up=True)[1]) == 0:
        sorted.append(event)
# sort based on velocity before movement

# %%
ma.count_events_in_array(session['behavior']['velocity_z_score'].values[400-100:400-20], 30, 0.1, threshold=3, up=True)[1]
# Out:
# []

# %%
sorted
# Out:
# [406,
#  412,
#  553,
#  569,
#  706,
#  708,
#  715,
#  725,
#  940,
#  2023,
#  2030,
#  2042,
#  2349,
#  23217,
#  23219,
#  23453,
#  23462,
#  23751,
#  23756,
#  23767,
#  23770,
#  23902,
#  23914,
#  23921,
#  24110,
#  24117,
#  24119,
#  24396,
#  24802]

# %%
plt.plot(session['behavior']['velocity_z_score'][24502:24802])

# %%
plt.plot(session['behavior']['velocity_z_score'][0:800])

# %%
plt.plot(session['C_z_scored'].mean(axis=1)[0:800])
