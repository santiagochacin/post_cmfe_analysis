# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
import numpy as np
from matplotlib import pyplot as plt
import itertools
import scipy.spatial.distance as dist

import sys
sys.path.append('/Users/johnmarshall/Documents/MATLAB/CNMF_E_jjm/python_wrapper/')
sys.path.append('/Users/johnmarshall/caiman_data/post_cnmfe_analysis')
import miniscope_analysis as ma 
import python_utils_jjm as utils_jjm
import jjm_post_cnmfe_fns as jjm
import align_msCam_tobehavior as align_tracking

# %%
# clean each matlab session 


# load multiple sessions 
_0_5000 = ma.miniscope_session('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN026/H16_M35_S34/memmap_0000memmap_0004_resized_source_extraction_run05/frames_1_5000/LOGS_24-Sep_16_07_53/out.mat')
_5000_10000 = ma.miniscope_session('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN026/H16_M35_S34/memmap_0005memmap_0009_resized_source_extraction_19:53:59.088/frames_1_5000/LOGS_09-Oct_20_00_02/out.mat')
_10000_15000 = ma.miniscope_session('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN026/H16_M35_S34/memmap_0010memmap_0014_resized_source_extraction_20:00:53.926/frames_1_5000/LOGS_09-Oct_20_07_56/out.mat')
_15000_20000 = ma.miniscope_session('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN026/H16_M35_S34/memmap_0015memmap_0019_resized_source_extraction_20:00:54.098/frames_1_5000/LOGS_09-Oct_20_07_03/out.mat')
_20000_25000 = ma.miniscope_session('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN026/H16_M35_S34/memmap_0020memmap_0024_resized_source_extraction_20:00:53.918/frames_1_5000/LOGS_09-Oct_20_07_53/out.mat')

sessions = [_0_5000, _5000_10000, _10000_15000, _15000_20000, _20000_25000]

# %%
# get centers of mass for each neuron
plt.rcParams['figure.figsize'] = [20, 20]
coordinates = []
for session in sessions:
    coordinates.append(utils_jjm.plot_contours(session.cnmfe_results['A'].todense(), session.cnmfe_results['Cn'], list_to_plot=range(np.shape(session.cnmfe_results['C'])[0]), display_numbers=True, maxthr=.6,cmap='gray', colors='r'))

coordinates = np.array(coordinates)

# %%
plt.rcParams['figure.figsize'] = [20, 20]
for session, color in zip([sessions[0], sessions[1]], ['r', 'b']):
    utils_jjm.plot_contours(session.cnmfe_results['A'].todense(), session.cnmfe_results['Cn'], list_to_plot=[1, 5], display_numbers=True, maxthr=.6,cmap='gray', colors=color)

# %%
# combine based on center of mass similarity 
coms = [] 
for session_coordinates in coordinates:
    coms.append([session_coordinates[x]['CoM'] for x in range(np.shape(session_coordinates)[0])])
np.array(coms)

coms_by_cell = {}
for session_num in range(len(coms)):
    for x in range(np.shape(coms[session_num])[0]):
        coms_by_cell[str(session_num)+'.'+str(x)] = coms[session_num][x]

# %%
coms_by_cell
# Out:
# {'0.0': array([311.25633126, 150.88443979]),
#  '0.1': array([176.82415407, 325.26084486]),
#  '0.2': array([254.27610749, 205.48635178]),
#  '0.3': array([325.10140583, 208.63159228]),
#  '0.4': array([192.67857585, 164.78026847]),
#  '0.5': array([180.89557997, 283.07643362]),
#  '0.6': array([152.69480941, 166.11486397]),
#  '0.7': array([282.29838728, 153.74254314]),
#  '0.8': array([261.97343796, 134.80720322]),
#  '2.9': array([349.44781227, 284.11047213]),
#  '2.10': array([295.94518933, 340.72095742]),
#  '2.11': array([286.98118402, 320.83017278]),
#  '2.12': array([207.06262812, 314.10888812]),
#  '2.13': array([292.02569548, 293.21205643]),
#  '3.0': array([312.36665424, 148.81409209]),
#  '3.1': array([254.30620803, 205.23475376]),
#  '3.2': array([181.10140638, 284.14187084]),
#  '3.3': array([204.2408705, 153.7797964]),
#  '3.4': array([224.86119829, 335.66308954]),
#  '3.5': array([253.96011501, 116.6654753 ]),
#  '3.6': array([346.29229644, 293.14653948]),
#  '3.7': array([325.78372467, 211.50247526]),
#  '3.8': array([255.67793177, 154.30439933]),
#  '3.9': array([264.76187433, 135.1310091 ]),
#  '3.10': array([438.3412242 , 441.84075182]),
#  '3.11': array([152.82796968, 166.17238195]),
#  '3.12': array([256.17356   , 152.16210003]),
#  '3.13': array([175.86648586, 332.46348293]),
#  '3.14': array([261.5157307 , 306.05395581]),
#  '3.15': array([216.55767206, 308.62172046]),
#  '3.16': array([206.13675861, 317.99529043]),
#  '3.17': array([301.23796403, 169.16524042]),
#  '3.18': array([257.48304347, 271.39155995]),
#  '3.19': array([244.34854537, 156.32299652]),
#  '3.20': array([260.57119467, 334.04276613]),
#  '3.21': array([215.00677869, 167.51316279]),
#  '3.22': array([392.97312193, 268.8203018 ]),
#  '3.23': array([249.31363354, 174.66191663]),
#  '3.24': array([285.45025858, 150.68331623]),
#  '3.25': array([311.39608549, 323.47009566]),
#  '3.26': array([256.27058953, 413.50789159]),
#  '3.27': array([325.39511044, 303.74183166]),
#  '3.28': array([238.22222264, 333.60453124]),
#  '3.29': array([265.56324112, 289.75271024]),
#  '3.30': array([228.45643216, 140.09969883]),
#  '3.31': array([354.34686191, 270.80081432]),
#  '3.32': array([261.15272457, 186.94898609]),
#  '3.33': array([191.50475819, 165.28176914]),
#  '3.34': array([274.60820342, 166.19858874]),
#  '3.35': array([206.02373776, 181.26341044]),
#  '3.36': array([365.52972418, 139.67631753]),
#  '3.37': array([326.03883628, 316.29459715]),
#  '3.38': array([283.16464029, 126.41739033]),
#  '3.39': array([190.23766802, 215.8858751 ]),
#  '3.40': array([301.01059049, 294.0573436 ]),
#  '3.41': array([337.32775892, 319.70002933]),
#  '3.42': array([200.63895239, 198.60920164]),
#  '3.43': array([331.45327169, 148.41726888]),
#  '3.44': array([257.22550216, 199.29112496]),
#  '3.45': array([216.29925942, 114.67390438]),
#  '3.46': array([244.61753291, 110.86036609]),
#  '3.47': array([215.80985089, 260.97564834]),
#  '3.48': array([218.97383666, 228.75317929]),
#  '3.49': array([436.67604118, 465.16281975]),
#  '3.50': array([506.0432448 , 326.99262002]),
#  '3.51': array([355.82922496, 103.41700946]),
#  '3.52': array([225.19128666, 125.91070687]),
#  '3.53': array([323.01216934, 197.03275456]),
#  '3.54': array([237.85732916, 245.17208149]),
#  '3.55': array([391.37752673, 293.03678488]),
#  '3.56': array([316.54842681, 133.94656904]),
#  '3.57': array([288.6007354 , 359.26883231]),
#  '3.58': array([361.52978869, 290.68163632]),
#  '3.59': array([332.14547061, 357.45173552]),
#  '3.60': array([294.82960592, 367.24429598]),
#  '3.61': array([387.91193056, 198.39204098]),
#  '3.62': array([285.83990503, 196.55622825]),
#  '3.63': array([475.14148546, 372.47715292]),
#  '3.64': array([289.02542629, 284.9632607 ]),
#  '3.65': array([309.67381793, 157.69848604]),
#  '3.66': array([256.08183377, 126.56427849]),
#  '3.67': array([177.88846028, 223.67881218]),
#  '3.68': array([244.77534881, 215.41294269]),
#  '3.69': array([183.98613462, 189.9521632 ]),
#  '3.70': array([224.28544815, 313.71542281]),
#  '3.71': array([318.16985212, 321.23909926]),
#  '3.72': array([312.86735016, 345.56685021]),
#  '3.73': array([195.82152384, 174.65322953]),
#  '3.74': array([212.44218075, 177.82443758]),
#  '3.75': array([365.83336779, 182.12218535]),
#  '4.0': array([327.58363967, 204.86390732]),
#  '4.1': array([313.56410234, 147.87153264]),
#  '4.2': array([260.20152688, 192.36857126]),
#  '4.3': array([443.6263698 , 440.46106468]),
#  '4.4': array([254.30214903, 202.14682531]),
#  '4.5': array([282.93323557, 152.67262705]),
#  '4.6': array([301.15263432, 167.59842821]),
#  '4.7': array([185.51191308, 280.20289739]),
#  '4.8': array([347.46820454, 292.29703334]),
#  '4.9': array([437.3874899 , 464.98843305]),
#  '4.10': array([250.92644178, 275.23299307]),
#  '4.11': array([156.74780018, 164.79163165]),
#  '4.12': array([207.75144201, 316.44664143]),
#  '4.13': array([311.8182833 , 386.91791811]),
#  '4.14': array([289.72937933, 293.52497115]),
#  '4.15': array([310.95003889, 173.78401254]),
#  '4.16': array([297.80011094, 256.64617868]),
#  '4.17': array([513.02120049, 310.56320335]),
#  '4.18': array([216.75245294, 306.3081653 ]),
#  '4.19': array([245.49061576, 135.3379901 ]),
#  '4.20': array([312.2108036 , 162.72705132]),
#  '4.21': array([250.37368668, 421.78651129]),
#  '4.22': array([324.2063087 , 215.36242224]),
#  '4.23': array([368.20077587, 265.35347711]),
#  '4.24': array([406.94457966, 437.91463976]),
#  '4.25': array([265.73606715, 267.28015747]),
#  '4.26': array([227.70056535, 111.9387294 ]),
#  '4.27': array([341.11514852, 239.4427393 ]),
#  '4.28': array([367.19502511, 119.25046782]),
#  '4.29': array([237.23611018, 236.23624968]),
#  '4.30': array([259.41127095, 407.38584019]),
#  '4.31': array([193.95126076, 165.2415911 ]),
#  '4.32': array([219.38507212, 337.54633924]),
#  '4.33': array([177.35475104, 334.32955748]),
#  '4.34': array([257.80376081, 152.7874922 ]),
#  '4.35': array([321.51790089, 303.83003253]),
#  '4.36': array([234.57799664, 329.39952595]),
#  '4.37': array([291.27060181, 368.42822661]),
#  '4.38': array([220.72632886, 227.72594537]),
#  '4.39': array([259.0270705 , 119.91831312]),
#  '4.40': array([315.54823023, 316.40071905]),
#  '4.41': array([287.25347408, 143.79004157]),
#  '4.42': array([479.78666576, 399.03525978]),
#  '4.43': array([357.64188208,  99.41860538]),
#  '4.44': array([200.66367103, 154.76162582]),
#  '4.45': array([346.64065939, 271.43570835]),
#  '4.46': array([332.47472795, 194.861516  ]),
#  '4.47': array([369.67091669, 136.49794514]),
#  '4.48': array([305.25393183, 275.94386828]),
#  '4.49': array([193.13692229, 212.96682227]),
#  '4.50': array([476.56566013, 371.9133113 ]),
#  '4.51': array([203.8363927, 190.9668293]),
#  '4.52': array([299.78785888, 357.43141064]),
#  '4.53': array([263.54354326, 184.07737111]),
#  '4.54': array([317.27851117, 136.12697124]),
#  '4.55': array([451.14045974, 405.5194824 ]),
#  '4.56': array([387.02594843, 202.07237135]),
#  '4.57': array([171.55229789, 296.62841185]),
#  '4.58': array([334.98623065, 264.61264084]),
#  '4.59': array([252.88165076, 210.34122073]),
#  '4.60': array([287.25734637, 352.78302332]),
#  '4.61': array([287.4200953 , 283.48450659]),
#  '4.62': array([446.70862615, 452.05809338]),
#  '4.63': array([352.82389163, 103.94458637]),
#  '4.64': array([213.49984409, 210.62339797])}

# %%
cell_permutations = np.array(list(itertools.permutations(coms_by_cell.keys(), 2)))

# %%
cell_permutations[0][0]
# Out:
# '0.0'

# %%
coms_by_cell[cell_permutations[0][0]]
# Out:
# array([311.25633126, 150.88443979])

# %%
cell_permutations[2][1][0]
# Out:
# '0'

# %%
#compile list of close cell pairs
overlapping_pairs = []
for pair in cell_permutations:
    if (dist.euclidean(coms_by_cell[pair[0]], coms_by_cell[pair[1]]) < 10) and (pair[0][0] != pair[1][0]):
        #check if cell already has a pair in the same session and only replce if distance is smaller
        if pair[0] in [pair[0] for pair in overlapping_pairs]:
            #print(pair)
            #gets the index with existing cell 1 of pair
            existing_index = len([pair[0] for pair in overlapping_pairs])-1
            #check if existing pair is in the same session
            if overlapping_pairs[existing_index][1][0] == pair[1][0]:
                #print(overlapping_pairs[existing_index])
                #print('    ' + overlapping_pairs[existing_index][1][0])
                #print(pair)
                #print('    ' + pair[1][0])
                #print(coms_by_cell[overlapping_pairs[existing_index]])
                #print(coms_by_cell[overlapping_pairs[existing_index]])
                if dist.euclidean(coms_by_cell[overlapping_pairs[existing_index][0]], coms_by_cell[overlapping_pairs[existing_index][1]]) > dist.euclidean(coms_by_cell[pair[0]], coms_by_cell[pair[1]]):
                    #remove existing index
                    overlapping_pairs.pop(existing_index)
                    #add existing
                    overlapping_pairs.append(pair)
            else:
                overlapping_pairs.append(pair)
        #check if cell was already previously assigned to a pair
        elif pair[0] in [pair[1] for pair in overlapping_pairs]:
            if pair[1] == overlapping_pairs[[pair[1] for pair in overlapping_pairs].index(pair[0])][0]:
                pass
        else:
            overlapping_pairs.append(pair)
# remove other duplicates            
for cell in [pair[1] for pair in overlapping_pairs]:
    if [pair[1] for pair in overlapping_pairs].count(cell) > 1:
        indicies_w_duplicates = [i for i, x in enumerate([pair[1] for pair in overlapping_pairs]) if x == cell]
        if dist.euclidean(coms_by_cell[overlapping_pairs[indicies_w_duplicates[0]][0]], coms_by_cell[overlapping_pairs[indicies_w_duplicates[0]][1]]) < dist.euclidean(coms_by_cell[overlapping_pairs[indicies_w_duplicates[1]][0]], coms_by_cell[overlapping_pairs[indicies_w_duplicates[1]][1]]):
              overlapping_pairs.pop(indicies_w_duplicates[1])
        else:
            overlapping_pairs.pop(indicies_w_duplicates[0])

# %%
# iterate over sessions
for session in range(1,5):
    if ('0.1' in [pair[0] for pair in overlapping_pairs]) and ('0.1'  in [overlapping_pairs[pair][0] for pair in range(len(overlapping_pairs)) if overlapping_pairs[pair][1][0]==str(session)]):
        #concactenate overlapped record to cell 
        print(True)
    else:
        #append list of zeros to z scores for this session 
        print(False)
# Out:
# True
# True
# False
# False
