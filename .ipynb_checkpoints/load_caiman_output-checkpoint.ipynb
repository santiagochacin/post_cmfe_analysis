# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import h5py
import pandas as pd
from caiman import mmapping as mmp
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
folder = '/Volumes/My_Passport/MiniscopeMovies/1_23_2019/GRIN_009_ACHf15/caiman_analysis/'
output_file = 'output_data.h5'

# %%
cnmfe_out = h5py.File(folder +'output_data.h5', 'r')
mmap_file_ms13 = mmp.load_memmap(folder + 'memmap_0012_d1_480_d2_752_d3_1_order_C_frames_1000_.mmap')

# %%
np.shape(C_array_ms9)

# %%
np.shape(C_array)

# %%
cnmfe_out

# %%
C_array = np.array(cnmfe_out['C'])

# %%
plt.plot(C_array[1][9000:10000])
plt.show()

# %%
plt.plot(C_array_ms9[2])
plt.show()

# %%
np.shape(C_array)
# Out:
# (9, 29000)
