# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import sys
import os
import glob
import importlib
import multiprocessing as mp
import itertools
import math
import random 

from matplotlib import pyplot as plt
import matplotlib.animation as animation
import scipy.sparse as sparse
import scipy.io as sio
import scipy.stats as stats
import scipy.spatial.distance as dist
import numpy as np
import h5py
from tqdm import tqdm
import pandas as pd
import tables
import deepdish as dd

sys.path.append('/Users/johnmarshall/Documents/Analysis/PythonAnalysisScripts/caimandata/post_cmfe_analysis')
import python_utils_jjm as jjm_utils

# %%
results_file = '/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN011/memmap_0005memmap_0009_resized_source_extraction_13:05:48.724/frames_1_5000/LOGS_15-Oct_13_12_40/15-Oct_13_48_21_2.mat_out.mat'
results = sio.loadmat(results_file)

# %% [markdown]
# ##A is spatial contours

# %%
#spatial footprints as 1d array
results['A']

# %%
img_file = '/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN011/H10_M19_S59msCam1.tif'
img_from_file = plt.imread(img_file)    
d1, d2 = np.shape(img_from_file)

# %%
results['A'][:, 1]
# Out:
# <360960x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1757 stored elements in Compressed Sparse Column format>

# %%
480*752
# Out:
# 360960

# %%
#reshape as 2d with original image dimensions
dense_A = results['A'].todense()
A_reshaped = np.reshape(dense_A[:, 1], (480, 752))

# %%
np.shape(A_reshaped)
# Out:
# (480, 752)

# %%
# if selecting frame subset  
Ctraces = results['C_raw'][1, :]

# %%
len(Ctraces)
# Out:
# 5000

# %%
movie_ = np.array([np.dot(A_reshaped, Ctraces[frame]) for frame in range(len(Ctraces))])

# %%
np.shape(movie_)
# Out:
# (5000, 480, 752)

# %%
print('            '+str(np.argmax(Ctraces)))
print('            '+str(np.argmin(Ctraces)))
# Out:
#             3336
#             1682

# %%
#lowest intensity frame
plt.imshow(movie_[1682])

# %%
#highest intensity frame
plt.imshow(movie_[3336])

# %%
import imageio

# %%
imageio.mimwrite('/Users/johnmarshall/Documents/Analysis/MiniscopeMovies/GRIN011/test_out.mp4', movie_, fps = 20)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 1.0717745411819348]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 1.1275409155240428]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 1.3439596237732658]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 1.1983078976331423]. Convert image to uint8 prior to saving to suppress this warning.
# ...
