# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import h5py
import pandas as pd
from caiman import mmapping as mmp
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
folder = '/Volumes/My_Passport/MiniscopeMovies/1_24_2019/GRIN_011_ACHf20/H10_M19_S59_caiman_analysis/'
output_file = 'output_data.h5'

# %%
cnmfe_out_ms9 = h5py.File('/Volumes/My_Passport/MiniscopeMovies/1_24_2019/GRIN_011_ACHf20/H10_M19_S59_ms9/memmap_0008_output_data.h5', 'r')
mmap_file_ms9 = mmp.load_memmap('/Volumes/My_Passport/MiniscopeMovies/1_24_2019/GRIN_011_ACHf20/H10_M19_S59_ms9/memmap_0008_d1_480_d2_752_d3_1_order_C_frames_1000_.mmap')

# %%
cnmfe_out = h5py.File(str(folder+output_file), 'r')

# %%
C_array_ms9 = np.array(cnmfe_out_ms9['C'])

# %%
np.shape(C_array_ms9)
# Out:
# (22, 1000)

# %%
np.shape(C_array)
# Out:
# (75, 19000)

# %%
cnmfe_out
# Out:
# <HDF5 file "output_data.h5" (mode r)>

# %%
C_array = np.array(cnmfe_out['C'])

# %%
plt.plot(C_array[2][9000:10000])
plt.show()

# %%
plt.plot(C_array_ms9[2])
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-05c7848b3bad> in <module>
# ----> 1 mmap_file_ms9[3]
#
# IndexError: tuple index out of range
