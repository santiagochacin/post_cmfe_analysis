# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import sys
import os
import glob
import importlib
import multiprocessing as mp

from matplotlib import pyplot as plt
import scipy.sparse as sparse
import scipy.io as sio
import scipy.stats as stats
import scipy.spatial.distance as dist
import numpy as np
import h5py
from tqdm import tqdm
import pandas as pd
import tables

sys.path.append('/Users/johnmarshall/Documents/MATLAB/CNMF_E/python_wrapper/')
sys.path.append('/Users/johnmarshall/caiman_data/demos/notebooks/post_cnmfe_analysis')
import python_utils as utils
import jjm_post_cnmfe_fns as jjm
from importlib import reload


# %matplotlib inline

# %%
reload(jjm)
# Out:
# <module 'jjm_post_cnmfe_fns' from '/Users/johnmarshall/Documents/Analysis/PythonAnalysisScripts/caimandata/post_cmfe_analysis/jjm_post_cnmfe_fns.py'>

# %%
# folder with matlab cnmfe output 
base_path = '/Volumes/My_Passport/MiniscopeMovies/1_23_2019/GRIN_009_ACHf15/questanalysisrun/'
#load a hdf files with pairwise comparisions
#glob.glob(base_path+'*resized_source_extraction')
results = jjm.get_results(base_path)
# Out:
# memmap_0000memmap_0004_resized_source_extraction
# memmap_0005memmap_0009_resized_source_extraction
# memmap_0010memmap_0014_resized_source_extraction
# memmap_0015memmap_0019_resized_source_extraction
# memmap_0020memmap_0024_resized_source_extraction
# memmap_0025memmap_0029_resized_source_extraction
# memmap_0030memmap_0034_resized_source_extraction
# memmap_0035memmap_0035_resized_source_extraction

# %%
eg_results = results['memmap_0005memmap_0009_resized_source_extraction']

# %%
eg_results['C_raw'][:,0:10]
# Out:
# array([[ 0.02300419,  0.00967416,  0.00550286, ...,  0.00936834,
#         -0.0236757 ,  0.00174996],
#        [ 0.14073175,  0.11232055,  0.18579505, ...,  0.095394  ,
#          0.13310969,  0.07692431],
#        [-0.00668736,  0.0265729 ,  0.06673411, ...,  0.10170982,
#         -0.02216967,  0.06088351],
#        ...,
#        [ 0.20024203,  0.06505129,  0.06961169, ...,  0.27099686,
#         -0.07511773,  0.02799391],
#        [-0.12993327, -0.00413684, -0.25969047, ..., -0.02522794,
#         -0.18269836, -0.02993863],
#        [-0.02786307, -0.08235962, -0.07708092, ..., -0.00960885,
#          0.04207667,  0.00749953]])

# %%
plt.plot(eg_results['C_raw'][150:,0:10])
plt.show()
